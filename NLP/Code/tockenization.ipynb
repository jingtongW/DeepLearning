# %%
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
raw_text =  """ 1. 사건명 : 2021회합116 회생
2. 채무자 : 주식회사 포티스
3. 관리인 : 최성일
4. 관할법원 : 수원지방법원

5. 회생계획 주요내용

1) 회생채권(금융기관대여금채권)

(1) 원금 및 개시 전 이자
시인된 원금 및 개시 전 이자의 84.90638%를 출자전환하고 15.09362%를 변제기일에 현금으로 변제합니다.
출자전환 대상 채권은 본 회생계획안 제8장 제4절에 의하여 채무자 회사가 발행하는 신주발행의 효력발생일에 당해 회생채권의 변제에 갈음하여 소멸합니다.
(2) 개시 후 이자
개시 후 이자는 전액 면제합니다.

2) 회생채권(일반대여금채권)

(1) 원금 및 개시 전 이자
시인된 원금 및 개시 전 이자의 84.90638%를 출자전환하고 15.09362%를 변제기일에 현금으로 변제합니다.
출자전환 대상 채권은 본 회생계획안 제8장 제4절에 의하여 채무자 회사가 발행하는 신주발행의 효력발생일에 당해 회생채권의 변제에 갈음하여 소멸합니다.
(2) 개시 후 이자
개시 후 이자는 전액 면제합니다.

3) 회생채권(확정구상채권)

(1) 원금 및 개시 전 이자
시인된 원금 및 개시 전 이자의 84.90638%를 출자전환하고 15.09362%를 변제기일에 현금으로 변제합니다.
출자전환 대상 채권은 본 회생계획안 제8장 제4절에 의하여 채무자 회사가 발행하는 신주발행의 효력발생일에 당해 회생채권의 변제에 갈음하여 소멸합니다.
(2) 개시 후 이자
개시 후 이자는 전액 면제합니다.

4) 회생채권(보증채권)

(1) 원금 및 개시 전 이자
시인된 원금 및 개시 전 이자의 84.90638%를 출자전환하고 15.09362%를 변제기일에 현금으로 변제합니다.
출자전환 대상 채권은 본 회생계획안 제8장 제4절에 의하여 채무자 회사가 발행하는 신주발행의 효력발생일에 당해 회생채권의 변제에 갈음하여 소멸합니다.
(2) 개시 후 이자
개시 후 이자는 전액 면제합니다.

5) 회생채권(전환사채권)

(1) 원금 및 개시 전 이자
시인된 원금 및 개시 전 이자의 84.90638%를 출자전환하고 15.09362%를 변제기일에 현금으로 변제합니다.
출자전환 대상 채권은 본 회생계획안 제8장 제4절에 의하여 채무자 회사가 발행하는 신주발행의 효력발생일에 당해 회생채권의 변제에 갈음하여 소멸합니다.
(2) 개시 후 이자
개시 후 이자는 전액 면제합니다.

6) 회생채권(상거래채권)

(1) 원금 및 개시 전 이자
시인된 원금 및 개시 전 이자의 84.90638%를 출자전환하고 15.09362%를 변제기일에 현금으로 변제합니다.
출자전환 대상 채권은 본 회생계획안 제8장 제4절에 의하여 채무자 회사가 발행하는 신주발행의 효력발생일에 당해 회생채권의 변제에 갈음하여 소멸합니다.
(2) 개시 후 이자
개시 후 이자는 전액 면제합니다.

7) 회생채권(손해배상채권)

(1) 원금 및 개시 전 이자
시인된 원금 및 개시 전 이자의 84.90638%를 출자전환하고 15.09362%를 변제기일에 현금으로 변제합니다.
출자전환 대상 채권은 본 회생계획안 제8장 제4절에 의하여 채무자 회사가 발행하는 신주발행의 효력발생일에 당해 회생채권의 변제에 갈음하여 소멸합니다.
(2) 개시 후 이자
개시 후 이자는 전액 면제합니다.

8) 회생채권(미발생구상채권)

(1) 대위변제금
보증기관이 채무자 회사를 위하여 채무를 대위변제하는 경우에는 대위변제금의 84.90638%를 출자전환하고 15.09362%를 현금으로 변제하되, 현금변제할 금액은 대위변제일이 속하는 달의 다음달 말일에 전액 변제합니다.
출자전환 대상 채권은 본 회생계획안 제8장 제4절에 의하여 채무자 회사가 발행하는 신주발행의 효력발생일에 당해 회생채권의 변제에 갈음하여 소멸합니다.

(2) 개시 후 이자
개시 후 이자는 전액 면제합니다.

9) 회생채권(미발생보증채권)

(1) 원금 및 개시전이자
원금 및 개시 전 이자는 우선 주채무자로부터 변제받도록 합니다.
채무자 회사의 회생계획인가일 이후 주채무자가 변제하여야 할 주채무를 이행하지 않고 그 불이행 상태가 1년(단, 주채무의 변제기일이 회생계획인가일 이후 도래하는 경우에는 그 변제기일로부터 1년)동안 계속되는 경우(이하 이 절에서 '채무자 회사가 변제할 사유'라 합니다)에는 변제되지 않은 회생채권 잔액의 84.90638%를 출자전환하고 15.09362%를 채무자 회사가 변제할 사유가 발생한 달의 다음달 말일에 전액 변제합니다.
출자전환 대상 채권은 본 회생계획안 제8장 제4절에 의하여 채무자 회사가 발행하는 신주발행의 효력발생일에 당해 회생채권의 변제에 갈음하여 소멸합니다.

(2) 개시 후 이자
개시 후 이자는 전액 면제합니다. """

# %%
sentences = sent_tokenize(raw_text)
sentences
# Out:
# [' 1.',
#  '사건명 : 2021회합116 회생\n2.',
#  '채무자 : 주식회사 포티스\n3.',
#  '관리인 : 최성일\n4.',
#  '관할법원 : 수원지방법원\n\n5.',
#  '회생계획 주요내용\n\n1) 회생채권(금융기관대여금채권)\n\n(1) 원금 및 개시 전 이자\n시인된 원금 및 개시 전 이자의 84.90638%를 출자전환하고 15.09362%를 변제기일에 현금으로 변제합니다.',
#  '출자전환 대상 채권은 본 회생계획안 제8장 제4절에 의하여 채무자 회사가 발행하는 신주발행의 효력발생일에 당해 회생채권의 변제에 갈음하여 소멸합니다.',
#  '(2) 개시 후 이자\n개시 후 이자는 전액 면제합니다.',
#  '2) 회생채권(일반대여금채권)\n\n(1) 원금 및 개시 전 이자\n시인된 원금 및 개시 전 이자의 84.90638%를 출자전환하고 15.09362%를 변제기일에 현금으로 변제합니다.',
#  '출자전환 대상 채권은 본 회생계획안 제8장 제4절에 의하여 채무자 회사가 발행하는 신주발행의 효력발생일에 당해 회생채권의 변제에 갈음하여 소멸합니다.',
#  '(2) 개시 후 이자\n개시 후 이자는 전액 면제합니다.',
#  '3) 회생채권(확정구상채권)\n\n(1) 원금 및 개시 전 이자\n시인된 원금 및 개시 전 이자의 84.90638%를 출자전환하고 15.09362%를 변제기일에 현금으로 변제합니다.',
#  '출자전환 대상 채권은 본 회생계획안 제8장 제4절에 의하여 채무자 회사가 발행하는 신주발행의 효력발생일에 당해 회생채권의 변제에 갈음하여 소멸합니다.',
#  '(2) 개시 후 이자\n개시 후 이자는 전액 면제합니다.',
#  '4) 회생채권(보증채권)\n\n(1) 원금 및 개시 전 이자\n시인된 원금 및 개시 전 이자의 84.90638%를 출자전환하고 15.09362%를 변제기일에 현금으로 변제합니다.',
#  '출자전환 대상 채권은 본 회생계획안 제8장 제4절에 의하여 채무자 회사가 발행하는 신주발행의 효력발생일에 당해 회생채권의 변제에 갈음하여 소멸합니다.',
#  '(2) 개시 후 이자\n개시 후 이자는 전액 면제합니다.',
#  '5) 회생채권(전환사채권)\n\n(1) 원금 및 개시 전 이자\n시인된 원금 및 개시 전 이자의 84.90638%를 출자전환하고 15.09362%를 변제기일에 현금으로 변제합니다.',
#  '출자전환 대상 채권은 본 회생계획안 제8장 제4절에 의하여 채무자 회사가 발행하는 신주발행의 효력발생일에 당해 회생채권의 변제에 갈음하여 소멸합니다.',
#  '(2) 개시 후 이자\n개시 후 이자는 전액 면제합니다.',
#  '6) 회생채권(상거래채권)\n\n(1) 원금 및 개시 전 이자\n시인된 원금 및 개시 전 이자의 84.90638%를 출자전환하고 15.09362%를 변제기일에 현금으로 변제합니다.',
#  '출자전환 대상 채권은 본 회생계획안 제8장 제4절에 의하여 채무자 회사가 발행하는 신주발행의 효력발생일에 당해 회생채권의 변제에 갈음하여 소멸합니다.',
#  '(2) 개시 후 이자\n개시 후 이자는 전액 면제합니다.',
#  '7) 회생채권(손해배상채권)\n\n(1) 원금 및 개시 전 이자\n시인된 원금 및 개시 전 이자의 84.90638%를 출자전환하고 15.09362%를 변제기일에 현금으로 변제합니다.',
#  '출자전환 대상 채권은 본 회생계획안 제8장 제4절에 의하여 채무자 회사가 발행하는 신주발행의 효력발생일에 당해 회생채권의 변제에 갈음하여 소멸합니다.',
#  '(2) 개시 후 이자\n개시 후 이자는 전액 면제합니다.',
#  '8) 회생채권(미발생구상채권)\n\n(1) 대위변제금\n보증기관이 채무자 회사를 위하여 채무를 대위변제하는 경우에는 대위변제금의 84.90638%를 출자전환하고 15.09362%를 현금으로 변제하되, 현금변제할 금액은 대위변제일이 속하는 달의 다음달 말일에 전액 변제합니다.',
#  '출자전환 대상 채권은 본 회생계획안 제8장 제4절에 의하여 채무자 회사가 발행하는 신주발행의 효력발생일에 당해 회생채권의 변제에 갈음하여 소멸합니다.',
#  '(2) 개시 후 이자\n개시 후 이자는 전액 면제합니다.',
#  '9) 회생채권(미발생보증채권)\n\n(1) 원금 및 개시전이자\n원금 및 개시 전 이자는 우선 주채무자로부터 변제받도록 합니다.',
#  "채무자 회사의 회생계획인가일 이후 주채무자가 변제하여야 할 주채무를 이행하지 않고 그 불이행 상태가 1년(단, 주채무의 변제기일이 회생계획인가일 이후 도래하는 경우에는 그 변제기일로부터 1년)동안 계속되는 경우(이하 이 절에서 '채무자 회사가 변제할 사유'라 합니다)에는 변제되지 않은 회생채권 잔액의 84.90638%를 출자전환하고 15.09362%를 채무자 회사가 변제할 사유가 발생한 달의 다음달 말일에 전액 변제합니다.",
#  '출자전환 대상 채권은 본 회생계획안 제8장 제4절에 의하여 채무자 회사가 발행하는 신주발행의 효력발생일에 당해 회생채권의 변제에 갈음하여 소멸합니다.',
#  '(2) 개시 후 이자\n개시 후 이자는 전액 면제합니다.']

# %%
sentences = word_tokenize(raw_text)
sentences
# Out:
# ['1',
#  '.',
#  '사건명',
#  ':',
#  '2021회합116',
#  '회생',
#  '2',
#  '.',
#  '채무자',
#  ':',
#  '주식회사',
#  '포티스',
#  '3',
#  '.',
#  '관리인',
#  ':',
#  '최성일',
#  '4',
#  '.',
#  '관할법원',
#  ':',
#  '수원지방법원',
#  '5',
#  '.',
#  '회생계획',
#  '주요내용',
#  '1',
#  ')',
#  '회생채권',
#  '(',
#  '금융기관대여금채권',
#  ')',
#  '(',
#  '1',
#  ')',
#  '원금',
#  '및',
#  '개시',
#  '전',
#  '이자',
#  '시인된',
#  '원금',
#  '및',
#  '개시',
#  '전',
#  '이자의',
#  '84.90638',
#  '%',
#  '를',
#  '출자전환하고',
#  '15.09362',
#  '%',
#  '를',
#  '변제기일에',
#  '현금으로',
#  '변제합니다',
#  '.',
#  '출자전환',
#  '대상',
#  '채권은',
#  '본',
#  '회생계획안',
#  '제8장',
#  '제4절에',
#  '의하여',
#  '채무자',
#  '회사가',
#  '발행하는',
#  '신주발행의',
#  '효력발생일에',
#  '당해',
#  '회생채권의',
#  '변제에',
#  '갈음하여',
#  '소멸합니다',
#  '.',
#  '(',
#  '2',
#  ')',
#  '개시',
#  '후',
#  '이자',
#  '개시',
#  '후',
#  '이자는',
#  '전액',
#  '면제합니다',
#  '.',
#  '2',
#  ')',
#  '회생채권',
#  '(',
#  '일반대여금채권',
#  ')',
#  '(',
#  '1',
#  ')',
#  '원금',
#  '및',
#  '개시',
#  '전',
#  '이자',
#  '시인된',
#  '원금',
#  '및',
#  '개시',
#  '전',
#  '이자의',
#  '84.90638',
#  '%',
#  '를',
#  '출자전환하고',
#  '15.09362',
#  '%',
#  '를',
#  '변제기일에',
#  '현금으로',
#  '변제합니다',
#  '.',
#  '출자전환',
#  '대상',
#  '채권은',
#  '본',
#  '회생계획안',
#  '제8장',
#  '제4절에',
#  '의하여',
#  '채무자',
#  '회사가',
#  '발행하는',
#  '신주발행의',
#  '효력발생일에',
#  '당해',
#  '회생채권의',
#  '변제에',
#  '갈음하여',
#  '소멸합니다',
#  '.',
#  '(',
#  '2',
#  ')',
#  '개시',
#  '후',
#  '이자',
#  '개시',
#  '후',
#  '이자는',
#  '전액',
#  '면제합니다',
#  '.',
#  '3',
#  ')',
#  '회생채권',
#  '(',
#  '확정구상채권',
#  ')',
#  '(',
#  '1',
#  ')',
#  '원금',
#  '및',
#  '개시',
#  '전',
#  '이자',
#  '시인된',
#  '원금',
#  '및',
#  '개시',
#  '전',
#  '이자의',
#  '84.90638',
#  '%',
#  '를',
#  '출자전환하고',
#  '15.09362',
#  '%',
#  '를',
#  '변제기일에',
#  '현금으로',
#  '변제합니다',
#  '.',
#  '출자전환',
#  '대상',
#  '채권은',
#  '본',
#  '회생계획안',
#  '제8장',
#  '제4절에',
#  '의하여',
#  '채무자',
#  '회사가',
#  '발행하는',
#  '신주발행의',
#  '효력발생일에',
#  '당해',
#  '회생채권의',
#  '변제에',
#  '갈음하여',
#  '소멸합니다',
#  '.',
#  '(',
#  '2',
#  ')',
#  '개시',
#  '후',
#  '이자',
#  '개시',
#  '후',
#  '이자는',
#  '전액',
#  '면제합니다',
#  '.',
#  '4',
#  ')',
#  '회생채권',
#  '(',
#  '보증채권',
#  ')',
#  '(',
#  '1',
#  ')',
#  '원금',
#  '및',
#  '개시',
#  '전',
#  '이자',
#  '시인된',
#  '원금',
#  '및',
#  '개시',
#  '전',
#  '이자의',
#  '84.90638',
#  '%',
#  '를',
#  '출자전환하고',
#  '15.09362',
#  '%',
#  '를',
#  '변제기일에',
#  '현금으로',
#  '변제합니다',
#  '.',
#  '출자전환',
#  '대상',
#  '채권은',
#  '본',
#  '회생계획안',
#  '제8장',
#  '제4절에',
#  '의하여',
#  '채무자',
#  '회사가',
#  '발행하는',
#  '신주발행의',
#  '효력발생일에',
#  '당해',
#  '회생채권의',
#  '변제에',
#  '갈음하여',
#  '소멸합니다',
#  '.',
#  '(',
#  '2',
#  ')',
#  '개시',
#  '후',
#  '이자',
#  '개시',
#  '후',
#  '이자는',
#  '전액',
#  '면제합니다',
#  '.',
#  '5',
#  ')',
#  '회생채권',
#  '(',
#  '전환사채권',
#  ')',
#  '(',
#  '1',
#  ')',
#  '원금',
#  '및',
#  '개시',
#  '전',
#  '이자',
#  '시인된',
#  '원금',
#  '및',
#  '개시',
#  '전',
#  '이자의',
#  '84.90638',
#  '%',
#  '를',
#  '출자전환하고',
#  '15.09362',
#  '%',
#  '를',
#  '변제기일에',
#  '현금으로',
#  '변제합니다',
#  '.',
#  '출자전환',
#  '대상',
#  '채권은',
#  '본',
#  '회생계획안',
#  '제8장',
#  '제4절에',
#  '의하여',
#  '채무자',
#  '회사가',
#  '발행하는',
#  '신주발행의',
#  '효력발생일에',
#  '당해',
#  '회생채권의',
#  '변제에',
#  '갈음하여',
#  '소멸합니다',
#  '.',
#  '(',
#  '2',
#  ')',
#  '개시',
#  '후',
#  '이자',
#  '개시',
#  '후',
#  '이자는',
#  '전액',
#  '면제합니다',
#  '.',
#  '6',
#  ')',
#  '회생채권',
#  '(',
#  '상거래채권',
#  ')',
#  '(',
#  '1',
#  ')',
#  '원금',
#  '및',
#  '개시',
#  '전',
#  '이자',
#  '시인된',
#  '원금',
#  '및',
#  '개시',
#  '전',
#  '이자의',
#  '84.90638',
#  '%',
#  '를',
#  '출자전환하고',
#  '15.09362',
#  '%',
#  '를',
#  '변제기일에',
#  '현금으로',
#  '변제합니다',
#  '.',
#  '출자전환',
#  '대상',
#  '채권은',
#  '본',
#  '회생계획안',
#  '제8장',
#  '제4절에',
#  '의하여',
#  '채무자',
#  '회사가',
#  '발행하는',
#  '신주발행의',
#  '효력발생일에',
#  '당해',
#  '회생채권의',
#  '변제에',
#  '갈음하여',
#  '소멸합니다',
#  '.',
#  '(',
#  '2',
#  ')',
#  '개시',
#  '후',
#  '이자',
#  '개시',
#  '후',
#  '이자는',
#  '전액',
#  '면제합니다',
#  '.',
#  '7',
#  ')',
#  '회생채권',
#  '(',
#  '손해배상채권',
#  ')',
#  '(',
#  '1',
#  ')',
#  '원금',
#  '및',
#  '개시',
#  '전',
#  '이자',
#  '시인된',
#  '원금',
#  '및',
#  '개시',
#  '전',
#  '이자의',
#  '84.90638',
#  '%',
#  '를',
#  '출자전환하고',
#  '15.09362',
#  '%',
#  '를',
#  '변제기일에',
#  '현금으로',
#  '변제합니다',
#  '.',
#  '출자전환',
#  '대상',
#  '채권은',
#  '본',
#  '회생계획안',
#  '제8장',
#  '제4절에',
#  '의하여',
#  '채무자',
#  '회사가',
#  '발행하는',
#  '신주발행의',
#  '효력발생일에',
#  '당해',
#  '회생채권의',
#  '변제에',
#  '갈음하여',
#  '소멸합니다',
#  '.',
#  '(',
#  '2',
#  ')',
#  '개시',
#  '후',
#  '이자',
#  '개시',
#  '후',
#  '이자는',
#  '전액',
#  '면제합니다',
#  '.',
#  '8',
#  ')',
#  '회생채권',
#  '(',
#  '미발생구상채권',
#  ')',
#  '(',
#  '1',
#  ')',
#  '대위변제금',
#  '보증기관이',
#  '채무자',
#  '회사를',
#  '위하여',
#  '채무를',
#  '대위변제하는',
#  '경우에는',
#  '대위변제금의',
#  '84.90638',
#  '%',
#  '를',
#  '출자전환하고',
#  '15.09362',
#  '%',
#  '를',
#  '현금으로',
#  '변제하되',
#  ',',
#  '현금변제할',
#  '금액은',
#  '대위변제일이',
#  '속하는',
#  '달의',
#  '다음달',
#  '말일에',
#  '전액',
#  '변제합니다',
#  '.',
#  '출자전환',
#  '대상',
#  '채권은',
#  '본',
#  '회생계획안',
#  '제8장',
#  '제4절에',
#  '의하여',
#  '채무자',
#  '회사가',
#  '발행하는',
#  '신주발행의',
#  '효력발생일에',
#  '당해',
#  '회생채권의',
#  '변제에',
#  '갈음하여',
#  '소멸합니다',
#  '.',
#  '(',
#  '2',
#  ')',
#  '개시',
#  '후',
#  '이자',
#  '개시',
#  '후',
#  '이자는',
#  '전액',
#  '면제합니다',
#  '.',
#  '9',
#  ')',
#  '회생채권',
#  '(',
#  '미발생보증채권',
#  ')',
#  '(',
#  '1',
#  ')',
#  '원금',
#  '및',
#  '개시전이자',
#  '원금',
#  '및',
#  '개시',
#  '전',
#  '이자는',
#  '우선',
#  '주채무자로부터',
#  '변제받도록',
#  '합니다',
#  '.',
#  '채무자',
#  '회사의',
#  '회생계획인가일',
#  '이후',
#  '주채무자가',
#  '변제하여야',
#  '할',
#  '주채무를',
#  '이행하지',
#  '않고',
#  '그',
#  '불이행',
#  '상태가',
#  '1년',
#  '(',
#  '단',
#  ',',
#  '주채무의',
#  '변제기일이',
#  '회생계획인가일',
#  '이후',
#  '도래하는',
#  '경우에는',
#  '그',
#  '변제기일로부터',
#  '1년',
#  ')',
#  '동안',
#  '계속되는',
#  '경우',
#  '(',
#  '이하',
#  '이',
#  '절에서',
#  "'채무자",
#  '회사가',
#  '변제할',
#  '사유',
#  "'",
#  '라',
#  '합니다',
#  ')',
#  '에는',
#  '변제되지',
#  '않은',
#  '회생채권',
#  '잔액의',
#  '84.90638',
#  '%',
#  '를',
#  '출자전환하고',
#  '15.09362',
#  '%',
#  '를',
#  '채무자',
#  '회사가',
#  '변제할',
#  '사유가',
#  '발생한',
#  '달의',
#  '다음달',
#  '말일에',
#  '전액',
#  '변제합니다',
#  '.',
#  '출자전환',
#  '대상',
#  '채권은',
#  '본',
#  '회생계획안',
#  '제8장',
#  '제4절에',
#  '의하여',
#  '채무자',
#  '회사가',
#  '발행하는',
#  '신주발행의',
#  '효력발생일에',
#  '당해',
#  '회생채권의',
#  '변제에',
#  '갈음하여',
#  '소멸합니다',
#  '.',
#  '(',
#  '2',
#  ')',
#  '개시',
#  '후',
#  '이자',
#  '개시',
#  '후',
#  '이자는',
#  '전액',
#  '면제합니다',
#  '.']

# %%
vocab = {}
preprocessed_sentences = []
stop_words = set(stopwords.words('english'))

# %%
for sentence in sentences:
    # 단어 토큰화
    tokenized_sentence = word_tokenize(sentence)
    result = []

    for word in tokenized_sentence: 
        word = word.lower() # 모든 단어를 소문자화하여 단어의 개수를 줄인다.
        if word not in stop_words: # 단어 토큰화 된 결과에 대해서 불용어를 제거한다.
            if len(word) > 2: # 단어 길이가 2이하인 경우에 대하여 추가로 단어를 제거한다.
                result.append(word)
                if word not in vocab:
                    vocab[word] = 0 
                vocab[word] += 1
    preprocessed_sentences.append(result)

# %%
print(vocab)
# Out:
# {'사건명': 1, '2021회합116': 1, '채무자': 13, '주식회사': 1, '포티스': 1, '관리인': 1, '최성일': 1, '관할법원': 1, '수원지방법원': 1, '회생계획': 1, '주요내용': 1, '회생채권': 10, '금융기관대여금채권': 1, '시인된': 7, '이자의': 7, '84.90638': 9, '출자전환하고': 9, '15.09362': 9, '변제기일에': 7, '현금으로': 8, '변제합니다': 9, '출자전환': 9, '채권은': 9, '회생계획안': 9, '제8장': 9, '제4절에': 9, '의하여': 9, '회사가': 11, '발행하는': 9, '신주발행의': 9, '효력발생일에': 9, '회생채권의': 9, '변제에': 9, '갈음하여': 9, '소멸합니다': 9, '이자는': 10, '면제합니다': 9, '일반대여금채권': 1, '확정구상채권': 1, '보증채권': 1, '전환사채권': 1, '상거래채권': 1, '손해배상채권': 1, '미발생구상채권': 1, '대위변제금': 1, '보증기관이': 1, '회사를': 1, '위하여': 1, '채무를': 1, '대위변제하는': 1, '경우에는': 2, '대위변제금의': 1, '변제하되': 1, '현금변제할': 1, '금액은': 1, '대위변제일이': 1, '속하는': 1, '다음달': 2, '말일에': 2, '미발생보증채권': 1, '개시전이자': 1, '주채무자로부터': 1, '변제받도록': 1, '합니다': 2, '회사의': 1, '회생계획인가일': 2, '주채무자가': 1, '변제하여야': 1, '주채무를': 1, '이행하지': 1, '불이행': 1, '상태가': 1, '주채무의': 1, '변제기일이': 1, '도래하는': 1, '변제기일로부터': 1, '계속되는': 1, '절에서': 1, "'채무자": 1, '변제할': 2, '변제되지': 1, '잔액의': 1, '사유가': 1, '발생한': 1}

# %%
sub_dict = vocab.items()

# %%
vocab_sorted = sorted(vocab.items(), key= lambda x : x[1], reverse= True)

# %%
vocab_sorted
# Out:
# [('채무자', 13),
#  ('회사가', 11),
#  ('회생채권', 10),
#  ('이자는', 10),
#  ('84.90638', 9),
#  ('출자전환하고', 9),
#  ('15.09362', 9),
#  ('변제합니다', 9),
#  ('출자전환', 9),
#  ('채권은', 9),
#  ('회생계획안', 9),
#  ('제8장', 9),
#  ('제4절에', 9),
#  ('의하여', 9),
#  ('발행하는', 9),
#  ('신주발행의', 9),
#  ('효력발생일에', 9),
#  ('회생채권의', 9),
#  ('변제에', 9),
#  ('갈음하여', 9),
#  ('소멸합니다', 9),
#  ('면제합니다', 9),
#  ('현금으로', 8),
#  ('시인된', 7),
#  ('이자의', 7),
#  ('변제기일에', 7),
#  ('경우에는', 2),
#  ('다음달', 2),
#  ('말일에', 2),
#  ('합니다', 2),
#  ('회생계획인가일', 2),
#  ('변제할', 2),
#  ('사건명', 1),
#  ('2021회합116', 1),
#  ('주식회사', 1),
#  ('포티스', 1),
#  ('관리인', 1),
#  ('최성일', 1),
#  ('관할법원', 1),
#  ('수원지방법원', 1),
#  ('회생계획', 1),
#  ('주요내용', 1),
#  ('금융기관대여금채권', 1),
#  ('일반대여금채권', 1),
#  ('확정구상채권', 1),
#  ('보증채권', 1),
#  ('전환사채권', 1),
#  ('상거래채권', 1),
#  ('손해배상채권', 1),
#  ('미발생구상채권', 1),
#  ('대위변제금', 1),
#  ('보증기관이', 1),
#  ('회사를', 1),
#  ('위하여', 1),
#  ('채무를', 1),
#  ('대위변제하는', 1),
#  ('대위변제금의', 1),
#  ('변제하되', 1),
#  ('현금변제할', 1),
#  ('금액은', 1),
#  ('대위변제일이', 1),
#  ('속하는', 1),
#  ('미발생보증채권', 1),
#  ('개시전이자', 1),
#  ('주채무자로부터', 1),
#  ('변제받도록', 1),
#  ('회사의', 1),
#  ('주채무자가', 1),
#  ('변제하여야', 1),
#  ('주채무를', 1),
#  ('이행하지', 1),
#  ('불이행', 1),
#  ('상태가', 1),
#  ('주채무의', 1),
#  ('변제기일이', 1),
#  ('도래하는', 1),
#  ('변제기일로부터', 1),
#  ('계속되는', 1),
#  ('절에서', 1),
#  ("'채무자", 1),
#  ('변제되지', 1),
#  ('잔액의', 1),
#  ('사유가', 1),
#  ('발생한', 1)]

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
preprocessed_sentences = [['barber', 'person'], ['barber', 'good', 'person'], ['barber', 'huge', 'person'], ['knew', 'secret'], ['secret', 'kept', 'huge', 'secret'], ['huge', 'secret'], ['barber', 'kept', 'word'], ['barber', 'kept', 'word'], ['barber', 'kept', 'secret'], ['keeping', 'keeping', 'huge', 'secret', 'driving', 'barber', 'crazy'], ['barber', 'went', 'huge', 'mountain']]

# %%
tokenizer = Tokenizer()

# fit_on_texts()안에 코퍼스를 입력으로 하면 빈도수를 기준으로 단어 집합을 생성.
tokenizer.fit_on_texts(preprocessed_sentences)

# %%
print(tokenizer.word_index)
# Out:
# {'barber': 1, 'secret': 2, 'huge': 3, 'kept': 4, 'person': 5, 'word': 6, 'keeping': 7, 'good': 8, 'knew': 9, 'driving': 10, 'crazy': 11, 'went': 12, 'mountain': 13}

# %%
print(tokenizer.texts_to_sequences(preprocessed_sentences))
# Out:
# [[1, 5], [1, 8, 5], [1, 3, 5], [9, 2], [2, 4, 3, 2], [3, 2], [1, 4, 6], [1, 4, 6], [1, 4, 2], [7, 7, 3, 2, 10, 1, 11], [1, 12, 3, 13]]
